# %% [markdown]
# # Brickset Sets Data
#
# Workflow: 3
#
# Goal: Loop over the sets' url data and get all the data fields.
#
# Result: The set urls are split into 4 jobs, the result of each job is output as a csv.

# %%
import os
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
import lego_helper as lh

# %% [markdown]
# ## Scrape One Set

# %%
# get data from a new set

TEST_URL = '/sets/10255-1/Assembly-Square'
set1_dx = lh.get_set_data(TEST_URL)
set1_dx
# Out:
# {'set_no': '10255-1',
#  'name': 'Assembly Square',
#  'url': '/sets/10255-1/Assembly-Square',
#  'set_type': 'Normal',
#  'theme_group': 'Model making',
#  'theme': 'Creator Expert',
#  'subtheme': 'Modular Buildings',
#  'year': '2017',
#  'tags': 'Anniversary Set, Apartment, Baby, Baked Goods, Ballet, Baseplate, Bathroom, Bbq, Camera, Carriage, Coffee Machine, Creator Expert, D2c, Dentist, Dog, Fine Arts, Fountain, Kitchen, Lamppost, Lego Tower, Microscale, Modular Building, Musical, Parrot, Restaurant, Shop, Wedding',
#  'piece_cnt': '4002',
#  'minifig_cnt': '9',
#  'inventory_url': '/inventories/10255-1',
#  'minifig_url': '/minifigs/inset-10255-1',
#  'store_price': '£179.99, $279.99, 239.99€',
#  'current_price': 'New: $215, Used: $185',
#  'packaging': 'Box',
#  'notes': 'Celebrates ten years of the Modular Buildings line.Connects with 10182-1 10185-1 10190-1 10197-1 10232-1 ',
#  'rating_value': '5.0',
#  'rating_votes': '5'}

# %%
# get data from a test set

TEST_URL = '/sets/722-1/Universal-Building-Set-7'  #'/sets/KC028-1/C-3PO'
set2_dx = lh.get_set_data(TEST_URL)
set2_dx
# Out:
# {'set_no': '722-1',
#  'name': 'Universal Building Set, 7+',
#  'url': '/sets/722-1/Universal-Building-Set-7',
#  'set_type': 'Normal',
#  'theme_group': 'Basic',
#  'theme': 'Basic',
#  'subtheme': None,
#  'year': '1980',
#  'tags': '4X4, Aircraft, Articulated Lorry, Boat, Car, Crane, Helicopter, Steam Roller, Trailer, Truck',
#  'piece_cnt': '301',
#  'minifig_cnt': 0,
#  'inventory_url': None,
#  'minifig_url': None,
#  'store_price': '$20.00',
#  'current_price': 'New: $200, Used: $78',
#  'packaging': None,
#  'notes': None,
#  'rating_value': '4.4',
#  'rating_votes': '5'}

# %%
set_ls = [set1_dx, set2_dx]
set_df = pd.DataFrame(set_ls)
set_df = set_df[['set_no', 'name', 'url', 
                 'theme_group', 'theme', 'subtheme',  
                 'year', 'piece_cnt', 'minifig_cnt', 'inventory_url', 'minifig_url', 
                 'store_price', 'current_price', 'rating_value', 'rating_votes', 
                 'tags', 'set_type', 'packaging', 'notes',]]
set_df.head()
set_df.info()
# Out:
#     set_no                        name                                   url  \
# 0  10255-1             Assembly Square         /sets/10255-1/Assembly-Square
# 1    722-1  Universal Building Set, 7+  /sets/722-1/Universal-Building-Set-7
#
#     theme_group           theme           subtheme  year piece_cnt  \
# 0  Model making  Creator Expert  Modular Buildings  2017      4002
# 1         Basic           Basic               None  1980       301
#
#   minifig_cnt         inventory_url              minifig_url  \
# 0           9  /inventories/10255-1  /minifigs/inset-10255-1
# 1           0                  None                     None
#
#                  store_price          current_price rating_value rating_votes  \
# 0  £179.99, $279.99, 239.99€  New: $215, Used: $185          5.0            5
# 1                     $20.00   New: $200, Used: $78          4.4            5
#
#                                                 tags set_type packaging  \
# 0  Anniversary Set, Apartment, Baby, Baked Goods,...   Normal       Box
# 1  4X4, Aircraft, Articulated Lorry, Boat, Car, C...   Normal      None
#
#                                                notes
# 0  Celebrates ten years of the Modular Buildings ...
# 1                                               None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 19 columns):
# set_no           2 non-null object
# name             2 non-null object
# url              2 non-null object
# theme_group      2 non-null object
# theme            2 non-null object
# subtheme         1 non-null object
# year             2 non-null object
# piece_cnt        2 non-null object
# minifig_cnt      2 non-null object
# inventory_url    1 non-null object
# minifig_url      1 non-null object
# store_price      2 non-null object
# current_price    2 non-null object
# rating_value     2 non-null object
# rating_votes     2 non-null object
# tags             2 non-null object
# set_type         2 non-null object
# packaging        1 non-null object
# notes            1 non-null object
# dtypes: object(19)
# memory usage: 384.0+ bytes

# %% [markdown]
# ## Scrape All Sets

# %%
URL_FILE = '../data/brickset_set_url.csv'
url_df = pd.read_csv(URL_FILE)
url_df.head()
url_df.info()
# Out:
#   set_no                                   name  \
# 0    722             Universal Building Set, 7+
# 1    733             Universal Building Set, 7+
# 2    744  Universal Building Set with Motor, 7+
# 3    820                  Red Plates Parts Pack
# 4    822                 Blue Plates Parts Pack
#
#                                                url
# 0             /sets/722-1/Universal-Building-Set-7
# 1             /sets/733-1/Universal-Building-Set-7
# 2  /sets/744-1/Universal-Building-Set-with-Motor-7
# 3                /sets/820-1/Red-Plates-Parts-Pack
# 4               /sets/822-1/Blue-Plates-Parts-Pack
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13899 entries, 0 to 13898
# Data columns (total 3 columns):
# set_no    13899 non-null object
# name      13897 non-null object
# url       13899 non-null object
# dtypes: object(3)
# memory usage: 325.8+ KB

# %%
# divide it into jobs for better error handling

url_0k_df = url_df[0:3499]
url_3k_df = url_df[3500:6999]
url_7k_df = url_df[7000:10499]
url_10k_df = url_df[10500:]

url_0k_df.shape
url_3k_df.shape
url_7k_df.shape
url_10k_df.shape
# Out:
# (3499, 3)
# (3499, 3)
# (3499, 3)
# (3399, 3)

# %%
set_ls = []

for idx, row in url_7k_df.iterrows():
    set_url = row['url']
    set_name = row['name']
    if idx % 200 == 0:
        print(f'{idx}: {set_url}')

    try:
        cset_dx = lh.get_set_data(set_url)
        set_ls.append(cset_dx)
    except Exception as ex:
        print(f'Row: {idx} {set_url}')
        print(f'Error: {ex}')
# Out:
# 7000: /sets/6243-1/Brickbeard-s-Bounty
# 7200: /sets/30008-1/Snowman
# 7400: /sets/MMMB006-1/House
# 7600: /sets/8195-1/Turbo-Tow
# 7800: /sets/852940-1/Princess-Tamina-Key-Chain
# 8000: /sets/3658-1/Police-Helicopter
# 8200: /sets/8805-3/Royal-Guard
# 8400: /sets/2852724-1/Accelerometer-Sensor
# Endpoint: https://brickset.com/sets/2853101-1/Gift-Card
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853101-1/Gift-Card
# Row: 8403 /sets/2853101-1/Gift-Card
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853101-1/Gift-Card
# Endpoint: https://brickset.com/sets/2853124-1/Gift-Card-Reload
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853124-1/Gift-Card-Reload
# Row: 8404 /sets/2853124-1/Gift-Card-Reload
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853124-1/Gift-Card-Reload
# Endpoint: https://brickset.com/sets/2853216-1/Infrared-Link-Sensor
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853216-1/Infrared-Link-Sensor
# Row: 8405 /sets/2853216-1/Infrared-Link-Sensor
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853216-1/Infrared-Link-Sensor
# Endpoint: https://brickset.com/sets/2853662-1/LEGO-Minifigure-Key-Light
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853662-1/LEGO-Minifigure-Key-Light
# Row: 8406 /sets/2853662-1/LEGO-Minifigure-Key-Light
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/2853662-1/LEGO-Minifigure-Key-Light
# 8600: /sets/4632-1/Building-Plates
# Endpoint: https://brickset.com/sets/8833-18/LEGO-Minifigures-Series-8-Sealed-Box
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/8833-18/LEGO-Minifigures-Series-8-Sealed-Box
# Row: 8731 /sets/8833-18/LEGO-Minifigures-Series-8-Sealed-Box
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/8833-18/LEGO-Minifigures-Series-8-Sealed-Box
# 8800: /sets/9490-1/Droid-Escape
# 9000: /sets/850457-1/LEGOLAND-Magnet
# 9200: /sets/NINJAGODVD-1/Ninjago-Masters-of-Spinjitzu-DVD
# Endpoint: https://brickset.com/sets/10507-1/My-First-Train-Set
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/10507-1/My-First-Train-Set
# Row: 9241 /sets/10507-1/My-First-Train-Set
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/10507-1/My-First-Train-Set
# Endpoint: https://brickset.com/sets/10508-1/Deluxe-Train-Set
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/10508-1/Deluxe-Train-Set
# Row: 9242 /sets/10508-1/Deluxe-Train-Set
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/10508-1/Deluxe-Train-Set
# Endpoint: https://brickset.com/sets/10509-1/Dusty-and-Chug
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/10509-1/Dusty-and-Chug
# Row: 9243 /sets/10509-1/Dusty-and-Chug
# Error: 524 Server Error: Origin Time-out for url: https://brickset.com/sets/10509-1/Dusty-and-Chug
# 9400: /sets/41017-1/Squirrel-s-Tree-House
# 9600: /sets/71001-12/Revolutionary-Soldier
# 9800: /sets/5002421-1/Legends-of-Chima-Laval-Minifigure-Clock
# 10000: /sets/30113-1/Stephanie-s-Bakery-Stand
# 10200: /sets/60061-1/Airport-Fire-Truck
# 10400: /sets/79121-1/Turtle-Sub-Undersea-Chase

# %%
set_df = pd.DataFrame(set_ls)
set_df = set_df[['set_no', 'name', 'url', 
                 'theme_group', 'theme', 'subtheme',  
                 'year', 'piece_cnt', 'minifig_cnt', 'inventory_url', 'minifig_url',  
                 'store_price', 'current_price', 'rating_value', 'rating_votes', 
                 'tags', 'set_type', 'packaging', 'notes',]]
set_df.head()
set_df.info()
# Out:
#    set_no                     name                                   url  \
# 0  6243-1      Brickbeard's Bounty      /sets/6243-1/Brickbeard-s-Bounty
# 1  6253-1        Shipwreck Hideout        /sets/6253-1/Shipwreck-Hideout
# 2  6299-1  Pirates Advent Calendar  /sets/6299-1/Pirates-Advent-Calendar
# 3  6741-1                 Mini Jet                 /sets/6741-1/Mini-Jet
# 4  6742-1          Mini Off-Roader          /sets/6742-1/Mini-Off-Roader
#
#     theme_group    theme  subtheme  year piece_cnt minifig_cnt  \
# 0    Historical  Pirates      None  2009       592           8
# 1    Historical  Pirates      None  2009       310           6
# 2    Historical  Pirates  Seasonal  2009       148           8
# 3  Model making  Creator      None  2009        63           0
# 4  Model making  Creator      None  2009        64           0
#
#          inventory_url             minifig_url     store_price  \
# 0  /inventories/6243-1  /minifigs/inset-6243-1  £59.99, $99.99
# 1  /inventories/6253-1  /minifigs/inset-6253-1  £26.45, $39.99
# 2  /inventories/6299-1  /minifigs/inset-6299-1          £15.79
# 3  /inventories/6741-1                    None    £4.99, $5.99
# 4  /inventories/6742-1                    None    £4.99, $5.99
#
#            current_price rating_value rating_votes  \
# 0  New: $215, Used: $133          4.5           21
# 1    New: $98, Used: $63          4.8           19
# 2    New: $49, Used: $35          5.0            5
# 3      New: $8, Used: $3          4.4            8
# 4      New: $9, Used: $4          4.3            6
#
#                                                 tags set_type packaging notes
# 0  Captain Brickbeard, Galleon, Monkey, Parrot, R...   Normal       Box  None
# 1  Captain Brickbeard, Crab, Criminal Hideout, Fi...   Normal       Box  None
# 2  Captain Brickbeard, Advent Calendar, Christmas...   Normal       Box  None
# 3  Aircraft, Jet Aircraft, Microscale, Multibuild...   Normal  Canister  None
# 4  Microscale, Multibuild, Off Roader, Telehandle...   Normal  Canister  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3491 entries, 0 to 3490
# Data columns (total 19 columns):
# set_no           3491 non-null object
# name             3491 non-null object
# url              3491 non-null object
# theme_group      3491 non-null object
# theme            3491 non-null object
# subtheme         2758 non-null object
# year             3491 non-null object
# piece_cnt        2570 non-null object
# minifig_cnt      3491 non-null object
# inventory_url    1922 non-null object
# minifig_url      1576 non-null object
# store_price      2745 non-null object
# current_price    3491 non-null object
# rating_value     1975 non-null object
# rating_votes     1975 non-null object
# tags             3491 non-null object
# set_type         3491 non-null object
# packaging        2464 non-null object
# notes            1572 non-null object
# dtypes: object(19)
# memory usage: 518.3+ KB

# %%
save_path = r'../data/brickset_set_data_7k.csv'
set_df.to_csv(save_path, index=False)
f'{round(os.path.getsize(save_path) /1e6, 2)} mb'
# Out:
# '0.92 mb'

# %%
set_ls = []

for idx, row in url_10k_df.iterrows():
    set_url = row['url']
    set_name = row['name']
    if idx % 200 == 0:
        print(f'{idx}: {set_url}')

    try:
        cset_dx = lh.get_set_data(set_url)
        set_ls.append(cset_dx)
    except Exception as ex:
        print(f'Error: {idx} {set_url}')
# Out:
# 10600: /sets/5004274-1/LEGO-Friends-Storage-Brick-1-Medium-Lilac
# 10800: /sets/40137-1/Submarine
# 11000: /sets/70781-1/Protector-of-Earth
# 11200: /sets/561507-1/Garden-set
# 11400: /sets/ISBN0241187567-1/LEGO-Ninjago-Build-Your-Own-Adventure
# 11600: /sets/41065-1/Rapunzel-s-Best-Day-Ever
# 11800: /sets/71011-7/Faun
# 12000: /sets/271601-1/Lance
# 12200: /sets/5005136-1/The-Force-Awakens-PS-4-Video-Game-–-Deluxe-Edition
# 12400: /sets/31062-1/Robo-Explorer
# 12600: /sets/70359-1/Lance-vs-Lightning
# 12800: /sets/76088-1/Thor-vs-Hulk-Arena-Clash
# 13000: /sets/5005355-1/Red-Blue-Brick-Print-Lunch-Bag
# 13200: /sets/30360-1/Arctic-Ice-Saw
# 13400: /sets/42082-1/Rough-Terrain-Crane
# 13600: /sets/75932-1/Jurassic-Park-Velociraptor-Chase
# 13800: /sets/5005533-1/Brick-Lunch-Bag-Black

# %%
set_df = pd.DataFrame(set_ls)
set_df = set_df[['set_no', 'name', 'url', 
                 'theme_group', 'theme', 'subtheme',  
                 'year', 'piece_cnt', 'minifig_cnt', 'inventory_url', 'minifig_url',  
                 'store_price', 'current_price', 'rating_value', 'rating_votes', 
                 'tags', 'set_type', 'packaging', 'notes',]]
set_df.head()
set_df.info()
# Out:
#       set_no                               name  \
# 0  5002912-1                    R2 D2 Key Light
# 1  5002913-1                 Superman Key Light
# 2  5002914-1     THE LEGO MOVIE Emmet Key Light
# 3  5002915-1                   Batman Key Light
# 4  5002916-1  The LEGO Movie Unikitty Key Light
#
#                                                  url    theme_group theme  \
# 0                    /sets/5002912-1/R2-D2-Key-Light  Miscellaneous  Gear
# 1                 /sets/5002913-1/Superman-Key-Light  Miscellaneous  Gear
# 2     /sets/5002914-1/THE-LEGO-MOVIE-Emmet-Key-Light  Miscellaneous  Gear
# 3                   /sets/5002915-1/Batman-Key-Light  Miscellaneous  Gear
# 4  /sets/5002916-1/The-LEGO-Movie-Unikitty-Key-Light  Miscellaneous  Gear
#
#   subtheme  year piece_cnt minifig_cnt inventory_url minifig_url  \
# 0   Lights  2014      None           0          None        None
# 1   Lights  2014      None           0          None        None
# 2   Lights  2014      None           0          None        None
# 3   Lights  2014      None           0          None        None
# 4   Lights  2014      None           0          None        None
#
#              store_price                    current_price rating_value  \
# 0           £9.99, 6.49€  New: Not known, Used: Not known          5.0
# 1  £9.99, $11.99, 12.99€  New: Not known, Used: Not known         None
# 2   £9.99, $11.99, 9.09€  New: Not known, Used: Not known         None
# 3          £9.99, 12.99€  New: Not known, Used: Not known         None
# 4   £9.99, $13.99, 9.09€  New: Not known, Used: Not known         None
#
#   rating_votes tags set_type packaging notes
# 0      1review          Gear      None  None
# 1         None          Gear      None  None
# 2         None          Gear      None  None
# 3         None          Gear      None  None
# 4         None          Gear      None  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3399 entries, 0 to 3398
# Data columns (total 19 columns):
# set_no           3399 non-null object
# name             3399 non-null object
# url              3399 non-null object
# theme_group      3399 non-null object
# theme            3399 non-null object
# subtheme         2866 non-null object
# year             3399 non-null object
# piece_cnt        2355 non-null object
# minifig_cnt      3399 non-null object
# inventory_url    1744 non-null object
# minifig_url      1647 non-null object
# store_price      2402 non-null object
# current_price    3399 non-null object
# rating_value     1509 non-null object
# rating_votes     1509 non-null object
# tags             3399 non-null object
# set_type         3399 non-null object
# packaging        2595 non-null object
# notes            1033 non-null object
# dtypes: object(19)
# memory usage: 504.6+ KB

# %%
save_path = r'../data/brickset_set_data_10k.csv'
set_df.to_csv(save_path, index=False)
f'{round(os.path.getsize(save_path) /1e6, 2)} mb'
# Out:
# '0.92 mb'
